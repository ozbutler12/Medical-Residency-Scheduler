# %% [markdown]
# # Initialize the dataframes

# %%
from google.colab import drive
from google.colab import files
drive.mount('/content/drive')
# %cd /content/drive/My Drive/Colab Notebooks
import pandas as pd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks

# %% [markdown]
# ---
#
# # Data Input from CSP File

# %%
data1 = {
  "Joseph Caravella": [1, 7, 2, 1, 3, 6, 4, 2, 1, 5, 3, 1],
  "Jordan Coffey": [2, 6, 7, 1, 5, 3, 1, 3, 1, 4, 2, 1],
  "Marcus Davis": [3, 1, 4, 3, 1, 2, 1, 5, 2, 1, 7, 6],
  "Jackson Weaver": [7, 2, 1, 4, 6, 1, 2, 1, 3, 1, 5, 3],
  "J.J. Westmoreland": [1, 3, 1, 2, 1, 7, 3, 6, 5, 2, 1, 4],
  "Hannah Willey": [6, 1, 3, 7, 2, 1, 5, 1, 4, 3, 1, 2]
}

data2 = {
  "Cody Bushyhead": [1, 4, 9, 1, 2, 8, 3, 1, 7, 5, 1, 6],
  "Prabh Khunkhun": [6, 7, 1, 8, 1, 9, 2, 1, 3, 4, 1, 5],
  "Jay Napolitano": [8, 1, 7, 9, 6, 5, 1, 3, 1, 2, 4, 1],
  "Andrew Oracz": [7, 6, 2, 5, 1, 4, 1, 9, 1, 3, 8, 1],
  "Natasha Rezvani": [1, 9, 1, 7, 8, 1, 5, 6, 2, 1, 3, 4],
  "Steven Vo": [9, 1, 8, 1, 7, 1, 6, 5, 4, 1, 2, 3]
}

data3 = {
  "Bryce Chapman": [1, 4, 1, 5, 1, 8, 7, 2, 6, 3, 1, 2],
  "Charlie Dean": [1, 2, 1, 7, 8, 6, 3, 1, 4, 1, 2, 5],
  "Read Founds": [6, 1, 5, 2, 1, 2, 4, 8, 3, 7, 1, 1],
  "Marshall Frieden": [8, 1, 7, 4, 6, 3, 2, 1, 2, 1, 5, 1],
  "Shonte Joseph": [3, 1, 2, 8, 2, 7, 6, 1, 5, 1, 1, 4],
  "Chris Van Hise": [2, 8, 3, 1, 4, 1, 1, 5, 1, 2, 6, 7]
}

# %% [markdown]
# # Creating the Dataframes

# %%
def year1(data1):
  # Convert the data to a DataFrame
  df1 = pd.DataFrame(data1)

  # Set the index to be the month names
  df1.index = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

  # Transpose the DataFrame so that the names are in the first column
  df1 = df1.transpose()

  # Rename the index to be 'Name'
  df1.index.name = 'Name'

  num_to_rotation = {
      1: 'Inpt',
      2: 'OBGYN',
      3: 'Peds',
      4: 'NICU',
      5: 'Emergency Med',
      6: 'Psych',
      7: 'Surg'
  }
  # Replace numbers with letters using the map() method
  for ind in df1:
    df1[ind] = df1[ind].map(num_to_rotation)

  return df1

# %%
def year2(data2):
  df2 = pd.DataFrame(data2)

  # Set the index to be the month names
  df2.index = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

  # Transpose the DataFrame so that the names are in the first column
  df2 = df2.transpose()

  # Rename the index to be 'Name'
  df2.index.name = 'Name'

  num_to_rotation = {
      1: 'Inpt',
      2: 'EM UMC',
      3: 'Gyn',
      4: 'Cards,',
      5: 'Crit Care',
      6: 'Amb Peds',
      7: 'Practice Mngmt',
      8: 'Peds EM',
      9: 'Ortho'
  }
  # Replace numbers with letters using the map() method
  for ind in df2:
    df2[ind] = df2[ind].map(num_to_rotation)

  # Print the DataFrame
  return df2

# %%
def year3(data3):
  # Convert the data to a DataFrame
  df3 = pd.DataFrame(data3)

  # Set the index to be the month names
  df3.index = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

  # Transpose the DataFrame so that the names are in the first column
  df3 = df3.transpose()

  # Rename the index to be 'Name'
  df3.index.name = 'Name'

  num_to_rotation = {
      1: 'Elective',
      2: 'Inpt',
      3: 'ENT/Opthal',
      4: 'Uro/Neuro,',
      5: 'MSK',
      6: 'Amb Peds',
      7: 'Comm Med',
      8: 'Peds EM',
      9: 'Derm'
  }
  # Replace numbers with letters using the map() method
  for ind in df3:
    df3[ind] = df3[ind].map(num_to_rotation)

  # Print the DataFrame
  return df3

# %%
df1=year1(data1)
df2=year2(data2)
df3=year3(data3)

# %% [markdown]
# ---
#
#
# # Year 1 Constraints

# %% [markdown]
# Constraints:
# *   Inpt cannot occur two months in a row for a student
# *   Each month two students must have Inpt
# * Inpt cannot be in a vacation month
# * Peds cannot be in a vacation month
# * Each student must take OBGYN twice
# * Each student must take Peds twice
# * Each student must take NICU, Emergency Med, Psych, and Surg one time
#
# Classes: Inpt, OBGYN, Peds, NICU, Emergency Med, Psych, Surg

# %%
df1
# Out:
#                      Jan    Feb    Mar    Apr            May    Jun  \
# Name
# Joseph Caravella    Inpt   Surg  OBGYN   Inpt           Peds  Psych
# Jordan Coffey      OBGYN  Psych   Surg   Inpt  Emergency Med   Peds
# Marcus Davis        Peds   Inpt   NICU   Peds           Inpt  OBGYN
# Jackson Weaver      Surg  OBGYN   Inpt   NICU          Psych   Inpt
# J.J. Westmoreland   Inpt   Peds   Inpt  OBGYN           Inpt   Surg
# Hannah Willey      Psych   Inpt   Peds   Surg          OBGYN   Inpt
#
#                              Jul            Aug            Sep            Oct  \
# Name
# Joseph Caravella            NICU          OBGYN           Inpt  Emergency Med
# Jordan Coffey               Inpt           Peds           Inpt           NICU
# Marcus Davis                Inpt  Emergency Med          OBGYN           Inpt
# Jackson Weaver             OBGYN           Inpt           Peds           Inpt
# J.J. Westmoreland           Peds          Psych  Emergency Med          OBGYN
# ...

# %% [markdown]
# # Year 2 Constraints

# %% [markdown]
# Constraints:
# * Each student needs Inpt 4 times
# * Inpt needs two people in it each month
# * Inpt cannot be in the same month as a vacation
# * EM UMC cannot be in the same month as a vacation
# * Everything else is needed only 1 time (Gyn,Cards,Crit Care,Amb Peds, EM UMC, Practice Mngmt, Peds EM, Ortho)
# * All classes besides INPT will have 1 student per month max
#
# Classes: Gyn, Cards, Crit Care, Amb Peds, EM UMC, Practice Mngmt, Peds EM, Ortho, Inpt

# %%
df2
# Out:
#                             Jan             Feb             Mar  \
# Name
# Cody Bushyhead             Inpt          Cards,           Ortho
# Prabh Khunkhun         Amb Peds  Practice Mngmt            Inpt
# Jay Napolitano          Peds EM            Inpt  Practice Mngmt
# Andrew Oracz     Practice Mngmt        Amb Peds          EM UMC
# Natasha Rezvani            Inpt           Ortho            Inpt
# Steven Vo                 Ortho            Inpt         Peds EM
#
#                             Apr             May        Jun        Jul  \
# Name
# Cody Bushyhead             Inpt          EM UMC    Peds EM        Gyn
# Prabh Khunkhun          Peds EM            Inpt      Ortho     EM UMC
# Jay Napolitano            Ortho        Amb Peds  Crit Care       Inpt
# Andrew Oracz          Crit Care            Inpt     Cards,       Inpt
# Natasha Rezvani  Practice Mngmt         Peds EM       Inpt  Crit Care
# Steven Vo                  Inpt  Practice Mngmt       Inpt   Amb Peds
#
# ...

# %% [markdown]
# # Year 3 Constraints

# %% [markdown]
# Constraints:
# * Each student needs Inpt 2 times
# * Each student needs Elective 4 times
# * Elective needs two people in it each month
# * Inpt cannot be in the same month as a vacation
# * ENT/Opthal and Uro/Neuro cannot be in a vacation month
# * Everything else is needed only 1 time (ENT/Ophthal, MSK, Amb Peds, Uro/Neuro, Comm Med, Derm)
# * All classes besides Elective will have 1 student per month max
#
# Classes: Inpt, Elective, ENT/Ophthal, MSK, Amb Peds, Uro/Neuro, Comm Med, Derm

# %%
df3
# Out:
#                          Jan         Feb         Mar         Apr         May  \
# Name
# Bryce Chapman       Elective  Uro/Neuro,    Elective         MSK    Elective
# Charlie Dean        Elective        Inpt    Elective    Comm Med     Peds EM
# Read Founds         Amb Peds    Elective         MSK        Inpt    Elective
# Marshall Frieden     Peds EM    Elective    Comm Med  Uro/Neuro,    Amb Peds
# Shonte Joseph     ENT/Opthal    Elective        Inpt     Peds EM        Inpt
# Chris Van Hise          Inpt     Peds EM  ENT/Opthal    Elective  Uro/Neuro,
#
#                          Jun         Jul       Aug         Sep         Oct  \
# Name
# Bryce Chapman        Peds EM    Comm Med      Inpt    Amb Peds  ENT/Opthal
# Charlie Dean        Amb Peds  ENT/Opthal  Elective  Uro/Neuro,    Elective
# Read Founds             Inpt  Uro/Neuro,   Peds EM  ENT/Opthal    Comm Med
# Marshall Frieden  ENT/Opthal        Inpt  Elective        Inpt    Elective
# ...
